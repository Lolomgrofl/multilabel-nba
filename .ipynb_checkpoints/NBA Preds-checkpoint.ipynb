# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

pd.set_option('max_columns', None)
# Out:
# D:\Development\Anaconda\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Data

# %%
games = pd.read_csv('./data/games.csv')
games_details = pd.read_csv('./data/games_details.csv')

players = pd.read_csv('./data/players.csv')

teams = pd.read_csv('./data/teams.csv')
ranking = pd.read_csv('./data/ranking.csv')

# %%
# games.head()
# games_details.head()

# %%
games['GAME_DATE_EST'] = pd.to_datetime(games['GAME_DATE_EST'], format='%Y-%m-%d')

# %% [markdown]
# ## GAMES DETAILS

# %%
df = pd.merge(games_details, games[['GAME_ID', 'SEASON', 'GAME_DATE_EST']], on='GAME_ID', how='inner')
df = df.sort_values('GAME_DATE_EST')

df['MIN'] = pd.to_numeric(df['MIN'].str.strip(':').str[0:2], errors='coerce')

# %%
last_n_games = [5, 10]
columns_to_agg = ['MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 
                  'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 
                  'STL', 'BLK', 'TO', 'PF', 'PTS', 'PLUS_MINUS']

for game in last_n_games:
    for col in columns_to_agg:
        df[f'AVG_{col}_LAST_{game}'] = df.groupby(['SEASON', 'PLAYER_ID'])[col].shift(1).rolling(game, min_periods=1).mean()
        
    df[f'GAMES_PLAYED_LAST_{game}'] = df.groupby(['SEASON', 'PLAYER_ID'])['MIN'].shift(1).rolling(game + 1, min_periods=1).count()/game

# %%
df.tail()
# Out:
#      GAME_ID     TEAM_ID TEAM_ABBREVIATION   TEAM_CITY  PLAYER_ID  \
# 59  42000142  1610612763               MEM     Memphis     203937
# 58  42000132  1610612752               NYK    New York    1629033
# 57  42000132  1610612752               NYK    New York     203658
# 71  42000142  1610612763               MEM     Memphis    1629723
# 0   42000102  1610612764               WAS  Washington     203078
#
#       PLAYER_NAME START_POSITION                 COMMENT   MIN   FGM   FGA  \
# 59  Kyle Anderson              F                     NaN  36.0   5.0   7.0
# 58    Theo Pinson            NaN  DNP - Coach's Decision   NaN   NaN   NaN
# 57   Norvel Pelle            NaN  DNP - Coach's Decision   NaN   NaN   NaN
# 71   John Konchar            NaN  DNP - Coach's Decision   NaN   NaN   NaN
# 0    Bradley Beal              F                     NaN  34.0  14.0  28.0
#
#     FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  \
# 59   0.714   1.0   2.0    0.500  0.0  0.0   0.000   1.0   5.0  6.0  3.0  4.0
# 58     NaN   NaN   NaN      NaN  NaN  NaN     NaN   NaN   NaN  NaN  NaN  NaN
# 57     NaN   NaN   NaN      NaN  NaN  NaN     NaN   NaN   NaN  NaN  NaN  NaN
# 71     NaN   NaN   NaN      NaN  NaN  NaN     NaN   NaN   NaN  NaN  NaN  NaN
# 0    0.500   1.0   6.0    0.167  4.0  6.0   0.667   0.0   4.0  4.0  3.0  1.0
#
#     BLK   TO   PF   PTS  PLUS_MINUS  SEASON GAME_DATE_EST  AVG_MIN_LAST_5  \
# 59  0.0  2.0  2.0  11.0         2.0    2020    2021-05-26       32.600000
# 58  NaN  NaN  NaN   NaN         NaN    2020    2021-05-26       32.000000
# 57  NaN  NaN  NaN   NaN         NaN    2020    2021-05-26       30.666667
# 71  NaN  NaN  NaN   NaN         NaN    2020    2021-05-26       26.500000
# 0   0.0  1.0  0.0  33.0       -22.0    2020    2021-05-26       35.000000
#
#     AVG_FGM_LAST_5  AVG_FGA_LAST_5  AVG_FG_PCT_LAST_5  AVG_FG3M_LAST_5  \
# 59        7.600000       15.800000           0.454800         0.800000
# 58        6.750000       14.500000           0.437500         1.000000
# 57        4.666667       10.666667           0.416667         0.666667
# 71        3.500000        9.000000           0.375000         1.000000
# 0         9.000000       16.500000           0.532500         1.000000
#
#     AVG_FG3A_LAST_5  AVG_FG3_PCT_LAST_5  AVG_FTM_LAST_5  AVG_FTA_LAST_5  \
# 59         2.600000            0.220000            2.60        3.600000
# 58         3.000000            0.275000            2.25        3.500000
# 57         2.333333            0.233333            2.00        2.666667
# 71         3.500000            0.350000            2.50        3.000000
# 0          4.000000            0.333500            4.50        5.000000
#
#     AVG_FT_PCT_LAST_5  AVG_OREB_LAST_5  AVG_DREB_LAST_5  AVG_REB_LAST_5  \
# 59             0.7500         2.400000         3.600000        6.000000
# 58             0.6875         2.750000         3.750000        6.500000
# 57             0.7500         2.666667         3.666667        6.333333
# 71             0.8750         1.000000         2.500000        3.500000
# 0              0.8750         1.500000         5.500000        7.000000
#
#     AVG_AST_LAST_5  AVG_STL_LAST_5  AVG_BLK_LAST_5  AVG_TO_LAST_5  \
# 59             2.4            2.40        0.800000       1.200000
# 58             2.0            2.75        1.000000       1.250000
# 57             2.0            3.00        0.666667       1.333333
# 71             1.5            4.50        0.500000       1.000000
# 0              4.5            3.50        0.000000       3.500000
#
#     AVG_PF_LAST_5  AVG_PTS_LAST_5  AVG_PLUS_MINUS_LAST_5  GAMES_PLAYED_LAST_5  \
# 59       3.600000           18.60               5.000000                  1.0
# 58       4.000000           16.75               4.750000                  0.8
# 57       4.666667           12.00               1.666667                  0.6
# 71       4.500000           10.50              -5.000000                  0.4
# 0        2.500000           23.50               2.500000                  0.4
#
#     AVG_MIN_LAST_10  AVG_FGM_LAST_10  AVG_FGA_LAST_10  AVG_FG_PCT_LAST_10  \
# 59        25.333333         4.500000        10.000000            0.385700
# 58        27.000000         4.777778        10.444444            0.391556
# 57        27.000000         5.375000        11.375000            0.440500
# 71        29.000000         6.142857        12.428571            0.503429
# 0         31.571429         7.714286        15.142857            0.512714
#
#     AVG_FG3M_LAST_10  AVG_FG3A_LAST_10  AVG_FG3_PCT_LAST_10  AVG_FTM_LAST_10  \
# 59          0.700000          2.000000             0.226700         1.500000
# 58          0.777778          2.222222             0.251889         1.444444
# 57          0.875000          2.500000             0.283375         1.625000
# 71          1.000000          2.571429             0.323857         1.857143
# 0           1.000000          3.142857             0.276286         2.714286
#
#     AVG_FTA_LAST_10  AVG_FT_PCT_LAST_10  AVG_OREB_LAST_10  AVG_DREB_LAST_10  \
# 59         2.100000            0.475000          1.600000          2.600000
# 58         2.111111            0.416667          1.666667          2.666667
# 57         2.375000            0.468750          1.750000          2.875000
# 71         2.714286            0.535714          1.857143          3.142857
# 0          3.428571            0.678571          2.142857          4.142857
#
#     AVG_REB_LAST_10  AVG_AST_LAST_10  AVG_STL_LAST_10  AVG_BLK_LAST_10  \
# 59         4.200000         1.800000         1.200000         0.500000
# 58         4.333333         1.666667         1.333333         0.555556
# 57         4.625000         1.875000         1.500000         0.625000
# 71         5.000000         1.857143         1.714286         0.571429
# 0          6.285714         2.714286         1.857143         0.571429
#
#     AVG_TO_LAST_10  AVG_PF_LAST_10  AVG_PTS_LAST_10  AVG_PLUS_MINUS_LAST_10  \
# 59        0.900000        2.300000        11.200000                1.500000
# 58        1.000000        2.555556        11.777778                2.000000
# 57        1.000000        2.625000        13.250000                3.500000
# 71        1.000000        2.857143        15.142857                5.428571
# 0         1.857143        2.571429        19.142857                6.285714
#
#     GAMES_PLAYED_LAST_10
# 59                   0.9
# 58                   0.8
# 57                   0.8
# 71                   0.7
# 0                    0.7

# %% [markdown]
# ## GAMES

# %%
col_home = ['GAME_DATE_EST', 'GAME_ID', 'HOME_TEAM_ID', 'SEASON', 
            'PTS_home', 'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 
            'AST_home', 'REB_home', 'HOME_TEAM_WINS']

col_guest = ['GAME_DATE_EST', 'GAME_ID', 'VISITOR_TEAM_ID', 'SEASON', 
            'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 
            'AST_away', 'REB_away', 'HOME_TEAM_WINS']

col_names = ['GAME_DATE_EST', 'GAME_ID', 'TEAM_ID', 'SEASON', 
            'PTS', 'FG_PCT', 'FT_PCT', 'FG3_PCT', 
            'AST', 'REB', 'TEAM_WINS']

games_home = games[col_home]
games_home.columns = col_names
games_home = games_home.sort_values('GAME_DATE_EST')

games_guest = games[col_guest]
games_guest['HOME_TEAM_WINS'] = 1 - games['HOME_TEAM_WINS']
games_guest.columns = col_names
games_guest = games_guest.sort_values('GAME_DATE_EST')

all_games = pd.concat([games_home, games_guest])
all_games = all_games.sort_values('GAME_DATE_EST')

# %% [markdown]
# # FIRST VERSION

# %%
df = df.drop('COMMENT',axis=1)

# %%
def fill_na_cat(dataset, columns):
    for column in columns:
        value_for_swap = dataset[column].describe().top
        dataset[column] = dataset[column].fillna(value_for_swap)
    return pd.DataFrame(dataset)
        

def fill_na_num(dataset, columns):
    for column in columns:
        value_for_swap = 0
        dataset[column] = dataset[column].fillna(value_for_swap)
    return pd.DataFrame(dataset)

numerics = df.select_dtypes(np.number)
cats = df.select_dtypes(object)


num_cols = list(numerics.columns)
cat_cols = list(cats.columns)

# %%
numerics = fill_na_num(numerics, num_cols)

df = pd.concat([cats, numerics], axis=1)

# %%
df['MIN'] = df['MIN'].fillna(0)

# %%
df['START_POSITION'] = df['START_POSITION'].fillna('G')

# %%
df.info()

# %%
testcol = df.groupby(['PLAYER_ID', 'SEASON'])['PTS'].shift(1).rolling(5, min_periods=1).mean()

# %%
testcol
