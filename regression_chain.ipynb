# %% [markdown]
# # LIBRARIES

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

pd.set_option('max_columns', None)
pd.set_option('max_rows', 80)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.multioutput import RegressorChain, MultiOutputRegressor

from sklearn.linear_model import RidgeCV, MultiTaskLasso, LinearRegression, ElasticNet, LassoCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

from sklearn.model_selection import cross_val_score, RepeatedKFold

from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# # DATA

# %%
df = pd.read_csv('Prepared Data/df.csv')
df = df.fillna(0)

# %%
year = 2018
idx_train = df['SEASON'] <= year
idx_test = df['SEASON'] > year

df_train = df.loc[idx_train, :]
df_test = df.loc[idx_test, :]

index_cols = ['PLAYER_ID', 'PLAYER_NAME', 'TEAM_ABBREVIATION', 'SEASON']

df_train = df_train.set_index(index_cols)
df_test = df_test.set_index(index_cols)

# %%
label_cols = ['PTS', 'REB', 'AST']

X_train, X_test = df_train.drop(label_cols, axis=1), df_test.drop(label_cols, axis=1)
y_train, y_test = df_train[label_cols], df_test[label_cols]

# %% [markdown]
# # HELP METHODS

# %%
def evaluate(y, y_hat):
    outputs = []
    
    outputs.append(mean_absolute_error(y, y_hat)) # GENERAL MAE
    outputs.append(np.sqrt(mean_squared_error(y, y_hat))) # GENERAL RMSE
    
    for i in range(y.shape[1]):
        outputs.append(mean_absolute_error(y.iloc[:, i], y_hat[:, i])) #SPECIFIC OUTPUT MAE
        outputs.append(mean_squared_error(y.iloc[:, i], y_hat[:, i])) #SPECIFIC OUTPUT RMSE
        
    return outputs

# %% [markdown]
# # MODELS

# %%
models = [LinearRegression(), 
          DecisionTreeRegressor(max_depth=5), RandomForestRegressor(n_estimators=20), 
          GradientBoostingRegressor(n_estimators=20)]
orders = [[0, 1, 2], [0, 2, 1], [1, 0, 2], [1, 2, 0], [2, 0, 1], [2, 1, 0]]

# %%
results = []

for model in models:
    for order in orders:
        wrapper = RegressorChain(model, order=order)
        wrapper.fit(X_train, y_train)
        
        y_hat_train = wrapper.predict(X_train)
        y_hat_test = wrapper.predict(X_test)
        
        results.append(['TRAIN', f'{order}', model.__class__.__name__, *evaluate(y_train, y_hat_train)])
        results.append(['TEST', f'{order}', model.__class__.__name__, *evaluate(y_test, y_hat_test)])
        with open(f'{model.__class__.__name__}-{order}.pickle', 'wb') as f:
            pickle.dump(wrapper, f)

# %%
results = pd.DataFrame(results, columns=['DATASET', 'ORDER','ALGORITHM',
                                         'GENERAL_MAE', 'GENERAL_RMSE', 
                                         'PTS_MAE', 'PTS_RMSE', 
                                         'REB_MAE', 'REB_RMSE', 
                                         'AST_MAE', 'AST_RMSE'])

results
# Out:
#    DATASET      ORDER                  ALGORITHM  GENERAL_MAE  GENERAL_RMSE  \
# 0    TRAIN  [0, 1, 2]           LinearRegression     3.576600      5.086739
# 1     TEST  [0, 1, 2]           LinearRegression     3.652095      5.301737
# 2    TRAIN  [0, 2, 1]           LinearRegression     3.576600      5.086739
# 3     TEST  [0, 2, 1]           LinearRegression     3.652095      5.301737
# 4    TRAIN  [1, 0, 2]           LinearRegression     3.576600      5.086739
# 5     TEST  [1, 0, 2]           LinearRegression     3.652095      5.301737
# 6    TRAIN  [1, 2, 0]           LinearRegression     3.576600      5.086739
# 7     TEST  [1, 2, 0]           LinearRegression     3.652095      5.301737
# 8    TRAIN  [2, 0, 1]           LinearRegression     3.576600      5.086739
# 9     TEST  [2, 0, 1]           LinearRegression     3.652095      5.301737
# 10   TRAIN  [2, 1, 0]           LinearRegression     3.576600      5.086739
# 11    TEST  [2, 1, 0]           LinearRegression     3.652095      5.301737
# 12   TRAIN  [0, 1, 2]      DecisionTreeRegressor     3.627667      5.121555
# 13    TEST  [0, 1, 2]      DecisionTreeRegressor     3.690568      5.349788
# 14   TRAIN  [0, 2, 1]      DecisionTreeRegressor     3.618280      5.120975
# 15    TEST  [0, 2, 1]      DecisionTreeRegressor     3.687128      5.352035
# 16   TRAIN  [1, 0, 2]      DecisionTreeRegressor     3.651617      5.153327
# 17    TEST  [1, 0, 2]      DecisionTreeRegressor     3.707477      5.369171
# 18   TRAIN  [1, 2, 0]      DecisionTreeRegressor     3.692551      5.226591
# 19    TEST  [1, 2, 0]      DecisionTreeRegressor     3.736255      5.406204
# 20   TRAIN  [2, 0, 1]      DecisionTreeRegressor     3.672315      5.166499
# 21    TEST  [2, 0, 1]      DecisionTreeRegressor     3.741486      5.366234
# 22   TRAIN  [2, 1, 0]      DecisionTreeRegressor     3.688485      5.225072
# 23    TEST  [2, 1, 0]      DecisionTreeRegressor     3.733710      5.406304
# 24   TRAIN  [0, 1, 2]      RandomForestRegressor     1.867925      2.550823
# 25    TEST  [0, 1, 2]      RandomForestRegressor     3.869952      5.492272
# 26   TRAIN  [0, 2, 1]      RandomForestRegressor     1.891018      2.593594
# 27    TEST  [0, 2, 1]      RandomForestRegressor     3.862076      5.477839
# 28   TRAIN  [1, 0, 2]      RandomForestRegressor     2.236202      3.490701
# 29    TEST  [1, 0, 2]      RandomForestRegressor     3.879137      5.505979
# 30   TRAIN  [1, 2, 0]      RandomForestRegressor     2.210780      3.704925
# 31    TEST  [1, 2, 0]      RandomForestRegressor     3.921486      5.559273
# 32   TRAIN  [2, 0, 1]      RandomForestRegressor     2.286648      3.599066
# 33    TEST  [2, 0, 1]      RandomForestRegressor     3.909246      5.535547
# 34   TRAIN  [2, 1, 0]      RandomForestRegressor     2.179520      3.658428
# 35    TEST  [2, 1, 0]      RandomForestRegressor     3.920497      5.567795
# 36   TRAIN  [0, 1, 2]  GradientBoostingRegressor     3.617651      5.112785
# 37    TEST  [0, 1, 2]  GradientBoostingRegressor     3.688725      5.357246
# 38   TRAIN  [0, 2, 1]  GradientBoostingRegressor     3.616946      5.112851
# 39    TEST  [0, 2, 1]  GradientBoostingRegressor     3.687496      5.357780
# 40   TRAIN  [1, 0, 2]  GradientBoostingRegressor     3.634005      5.133160
# 41    TEST  [1, 0, 2]  GradientBoostingRegressor     3.691224      5.360587
# 42   TRAIN  [1, 2, 0]  GradientBoostingRegressor     3.659607      5.166618
# 43    TEST  [1, 2, 0]  GradientBoostingRegressor     3.703424      5.361245
# 44   TRAIN  [2, 0, 1]  GradientBoostingRegressor     3.645866      5.135005
# 45    TEST  [2, 0, 1]  GradientBoostingRegressor     3.701119      5.352707
# 46   TRAIN  [2, 1, 0]  GradientBoostingRegressor     3.656547      5.164441
# 47    TEST  [2, 1, 0]  GradientBoostingRegressor     3.701167      5.360895
#
#      PTS_MAE   PTS_RMSE   REB_MAE   REB_RMSE   AST_MAE  AST_RMSE
# 0   6.081095  58.828647  2.710256  12.262307  1.938448  6.533783
